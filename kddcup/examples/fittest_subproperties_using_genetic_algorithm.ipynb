# %%
from kddcup.evolution import Population
from kddcup.core.constants import kddcup_properties
# Out:
# ---------------------------------------------
# ModuleNotFoundErrorTraceback (most recent call last)
# <ipython-input-1-23b5813b55f0> in <module>()
# ----> 1 from kddcup.evolution import Population
#       2 from kddcup.core.constants import kddcup_properties
#
# ModuleNotFoundError: No module named 'kddcup'

# %% [markdown]
# Set some constants

# %%
space = kddcup_properties[:-1] # Space of properties to search
train_env = '~/.kddcup/kddcup.data_10_percent_corrected' # evolution training environment
test_env = '~/.kddcup/corrected' # evolution testing environment
pop_size = 3 # How many subproperties
brain = [] # Individual brain configuration
NGEN = 2 # Number of generation

# %%
pop = Population(space=space, size=3).evolve(train_env=train_env, test_env=test_env, NGEN=2)
# Out:
# GENERATION  2
#
#     Population:  [11, 28, 35]
# /home/mctrjalloh/.virtualenvs/ml/lib/python3.5/site-packages/kddcup/core/data.py:59: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.current['attack_type'] = updated
# Training..
# Training..
# Training..
# Training..
# Training..
# Training..
# Training..
# Training..
# Training..
# Skipping..
# Testing..
# 10000/10000 [==============================] - 0s 48us/step
# inputs:  ['diff_srv_rate', 'dst_host_rerror_rate', 'dst_host_srv_serror_rate', 'hot', 'num_access_files', 'num_compromised', 'num_file_creations', 'protocol_type', 'root_shell', 'srv_diff_host_rate', 'urgent']
# targets:  ['normal.', 'other.']
# loss:  1.2518684843063355
# accuracy:  0.1209
# Training..
# Training..
# Training..
# Training..
# Training..
# Training..
# Training..
# Training..
# Training..
# Skipping..
# Testing..
# 10000/10000 [==============================] - 1s 52us/step
# inputs:  ['count', 'dst_bytes', 'dst_host_count', 'dst_host_diff_srv_rate', 'dst_host_rerror_rate', 'dst_host_same_src_port_rate', 'dst_host_same_srv_rate', 'dst_host_srv_count', 'dst_host_srv_diff_host_rate', 'dst_host_srv_serror_rate', 'is_guest_login', 'is_host_login', 'logged_in', 'num_access_files', 'num_compromised', 'num_file_creations', 'num_outbound_cmds', 'protocol_type', 'rerror_rate', 'same_srv_rate', 'service', 'srv_count', 'srv_diff_host_rate', 'srv_rerror_rate', 'srv_serror_rate', 'su_attempted', 'urgent', 'wrong_fragment']
# targets:  ['normal.', 'other.']
# loss:  0.941057435131073
# accuracy:  0.1209
# Training..
# Training..
# Training..
# Training..
# Training..
# Training..
# Training..
# Training..
# Training..
# Skipping..
# Testing..
# 10000/10000 [==============================] - 1s 52us/step
# inputs:  ['count', 'diff_srv_rate', 'dst_bytes', 'dst_host_count', 'dst_host_diff_srv_rate', 'dst_host_rerror_rate', 'dst_host_same_src_port_rate', 'dst_host_same_srv_rate', 'dst_host_serror_rate', 'dst_host_srv_count', 'dst_host_srv_diff_host_rate', 'dst_host_srv_rerror_rate', 'duration', 'flag', 'hot', 'is_guest_login', 'is_host_login', 'land', 'logged_in', 'num_access_files', 'num_compromised', 'num_failed_logins', 'num_outbound_cmds', 'num_root', 'num_shells', 'protocol_type', 'rerror_rate', 'same_srv_rate', 'serror_rate', 'src_bytes', 'srv_count', 'srv_diff_host_rate', 'srv_serror_rate', 'su_attempted', 'urgent']
# targets:  ['normal.', 'other.']
# loss:  0.9408758973121643
# accuracy:  0.1209
# Training..
# Training..
# Training..
# Training..
# Training..
# Training..
# Training..
# Training..
# Training..
# Skipping..
# Testing..
# 10000/10000 [==============================] - 1s 72us/step
# inputs:  ['count', 'diff_srv_rate', 'dst_bytes', 'dst_host_count', 'dst_host_diff_srv_rate', 'dst_host_rerror_rate', 'dst_host_same_src_port_rate', 'dst_host_same_srv_rate', 'dst_host_serror_rate', 'dst_host_srv_count', 'dst_host_srv_diff_host_rate', 'dst_host_srv_rerror_rate', 'duration', 'flag', 'hot', 'is_guest_login', 'is_host_login', 'land', 'logged_in', 'num_access_files', 'num_compromised', 'num_failed_logins', 'num_outbound_cmds', 'num_root', 'num_shells', 'protocol_type', 'rerror_rate', 'same_srv_rate', 'serror_rate', 'src_bytes', 'srv_count', 'srv_diff_host_rate', 'srv_serror_rate', 'su_attempted', 'urgent']
# targets:  ['normal.', 'other.']
# loss:  0.9421870951652527
# accuracy:  0.1209
# Training..
# Training..
# Training..
# Training..
# Training..
# Training..
# Training..
# Training..
# Training..
# Skipping..
# Testing..
# 10000/10000 [==============================] - 1s 60us/step
# inputs:  ['count', 'diff_srv_rate', 'dst_bytes', 'dst_host_count', 'dst_host_diff_srv_rate', 'dst_host_rerror_rate', 'dst_host_same_src_port_rate', 'dst_host_same_srv_rate', 'dst_host_serror_rate', 'dst_host_srv_count', 'dst_host_srv_diff_host_rate', 'dst_host_srv_rerror_rate', 'duration', 'flag', 'hot', 'is_guest_login', 'is_host_login', 'land', 'logged_in', 'num_access_files', 'num_compromised', 'num_failed_logins', 'num_outbound_cmds', 'num_root', 'num_shells', 'protocol_type', 'rerror_rate', 'same_srv_rate', 'serror_rate', 'src_bytes', 'srv_count', 'srv_diff_host_rate', 'srv_serror_rate', 'su_attempted', 'urgent']
# targets:  ['normal.', 'other.']
# loss:  0.9405585457801818
# accuracy:  0.1209
# Training..
# Training..
# Training..
# Training..
# Training..
# Training..
# Training..
# Training..
# Training..
# Skipping..
# Testing..
# 10000/10000 [==============================] - 1s 65us/step
# inputs:  ['count', 'diff_srv_rate', 'dst_bytes', 'dst_host_count', 'dst_host_diff_srv_rate', 'dst_host_rerror_rate', 'dst_host_same_src_port_rate', 'dst_host_same_srv_rate', 'dst_host_serror_rate', 'dst_host_srv_count', 'dst_host_srv_diff_host_rate', 'dst_host_srv_rerror_rate', 'duration', 'flag', 'hot', 'is_guest_login', 'is_host_login', 'land', 'logged_in', 'num_access_files', 'num_compromised', 'num_failed_logins', 'num_outbound_cmds', 'num_root', 'num_shells', 'protocol_type', 'rerror_rate', 'same_srv_rate', 'serror_rate', 'src_bytes', 'srv_count', 'srv_diff_host_rate', 'srv_serror_rate', 'su_attempted', 'urgent']
# targets:  ['normal.', 'other.']
# loss:  1.1864234479904174
# accuracy:  0.1209
#
# GENERATION  1
#
#     Population:  [35, 35, 35]
# Training..
# Training..
# Training..
# Training..
# Training..
# Training..
# Training..
# Training..
# Training..
# Skipping..
# Testing..
# 10000/10000 [==============================] - 1s 62us/step
# inputs:  ['count', 'diff_srv_rate', 'dst_bytes', 'dst_host_count', 'dst_host_diff_srv_rate', 'dst_host_rerror_rate', 'dst_host_same_src_port_rate', 'dst_host_same_srv_rate', 'dst_host_serror_rate', 'dst_host_srv_count', 'dst_host_srv_diff_host_rate', 'dst_host_srv_rerror_rate', 'duration', 'flag', 'hot', 'is_guest_login', 'is_host_login', 'land', 'logged_in', 'num_access_files', 'num_compromised', 'num_failed_logins', 'num_outbound_cmds', 'num_root', 'num_shells', 'protocol_type', 'rerror_rate', 'same_srv_rate', 'serror_rate', 'src_bytes', 'srv_count', 'srv_diff_host_rate', 'srv_serror_rate', 'su_attempted', 'urgent']
# targets:  ['normal.', 'other.']
# loss:  0.9422699926376342
# accuracy:  0.1209
# Training..
# Training..
# Training..
# Training..
# Training..
# Training..
# Training..
# Training..
# Training..
# Skipping..
# Testing..
# 10000/10000 [==============================] - 1s 67us/step
# inputs:  ['count', 'diff_srv_rate', 'dst_bytes', 'dst_host_count', 'dst_host_diff_srv_rate', 'dst_host_rerror_rate', 'dst_host_same_src_port_rate', 'dst_host_same_srv_rate', 'dst_host_serror_rate', 'dst_host_srv_count', 'dst_host_srv_diff_host_rate', 'dst_host_srv_rerror_rate', 'duration', 'flag', 'hot', 'is_guest_login', 'is_host_login', 'land', 'logged_in', 'num_access_files', 'num_compromised', 'num_failed_logins', 'num_outbound_cmds', 'num_root', 'num_shells', 'protocol_type', 'rerror_rate', 'same_srv_rate', 'serror_rate', 'src_bytes', 'srv_count', 'srv_diff_host_rate', 'srv_serror_rate', 'su_attempted', 'urgent']
# targets:  ['normal.', 'other.']
# loss:  0.9419954609870911
# accuracy:  0.1209
# Training..
# Training..
# Training..
# Training..
# Training..
# Training..
# Training..
# Training..
# Training..
# Skipping..
# Testing..
# 10000/10000 [==============================] - 1s 65us/step
# inputs:  ['count', 'diff_srv_rate', 'dst_bytes', 'dst_host_count', 'dst_host_diff_srv_rate', 'dst_host_rerror_rate', 'dst_host_same_src_port_rate', 'dst_host_same_srv_rate', 'dst_host_serror_rate', 'dst_host_srv_count', 'dst_host_srv_diff_host_rate', 'dst_host_srv_rerror_rate', 'duration', 'flag', 'hot', 'is_guest_login', 'is_host_login', 'land', 'logged_in', 'num_access_files', 'num_compromised', 'num_failed_logins', 'num_outbound_cmds', 'num_root', 'num_shells', 'protocol_type', 'rerror_rate', 'same_srv_rate', 'serror_rate', 'src_bytes', 'srv_count', 'srv_diff_host_rate', 'srv_serror_rate', 'su_attempted', 'urgent']
# targets:  ['normal.', 'other.']
# loss:  1.1441811149597167
# accuracy:  0.1209
# Training..
# Training..
# Training..
# Training..
# Training..
# Training..
# Training..
# Training..
# Training..
# Skipping..
# Testing..
# 10000/10000 [==============================] - 1s 75us/step
# inputs:  ['count', 'diff_srv_rate', 'dst_bytes', 'dst_host_count', 'dst_host_diff_srv_rate', 'dst_host_rerror_rate', 'dst_host_same_src_port_rate', 'dst_host_same_srv_rate', 'dst_host_serror_rate', 'dst_host_srv_count', 'dst_host_srv_diff_host_rate', 'dst_host_srv_rerror_rate', 'duration', 'flag', 'hot', 'is_guest_login', 'is_host_login', 'land', 'logged_in', 'num_access_files', 'num_compromised', 'num_failed_logins', 'num_outbound_cmds', 'num_root', 'num_shells', 'protocol_type', 'rerror_rate', 'same_srv_rate', 'serror_rate', 'src_bytes', 'srv_count', 'srv_diff_host_rate', 'srv_serror_rate', 'su_attempted', 'urgent']
# targets:  ['normal.', 'other.']
# loss:  0.9418393471717834
# accuracy:  0.1209
# Training..
# Training..
# Training..
# Training..
# Training..
# Training..
# Training..
# Training..
# Training..
# Skipping..
# Testing..
# 10000/10000 [==============================] - 1s 68us/step
# inputs:  ['count', 'diff_srv_rate', 'dst_bytes', 'dst_host_count', 'dst_host_diff_srv_rate', 'dst_host_rerror_rate', 'dst_host_same_src_port_rate', 'dst_host_same_srv_rate', 'dst_host_serror_rate', 'dst_host_srv_count', 'dst_host_srv_diff_host_rate', 'dst_host_srv_rerror_rate', 'duration', 'flag', 'hot', 'is_guest_login', 'is_host_login', 'land', 'logged_in', 'num_access_files', 'num_compromised', 'num_failed_logins', 'num_outbound_cmds', 'num_root', 'num_shells', 'protocol_type', 'rerror_rate', 'same_srv_rate', 'serror_rate', 'src_bytes', 'srv_count', 'srv_diff_host_rate', 'srv_serror_rate', 'su_attempted', 'urgent']
# targets:  ['normal.', 'other.']
# loss:  0.9419208507537842
# accuracy:  0.1209
# Training..
# Training..
# Training..
# Training..
# Training..
# Training..
# Training..
# Training..
# Training..
# Skipping..
# Testing..
# 10000/10000 [==============================] - 1s 76us/step
# inputs:  ['count', 'diff_srv_rate', 'dst_bytes', 'dst_host_count', 'dst_host_diff_srv_rate', 'dst_host_rerror_rate', 'dst_host_same_src_port_rate', 'dst_host_same_srv_rate', 'dst_host_serror_rate', 'dst_host_srv_count', 'dst_host_srv_diff_host_rate', 'dst_host_srv_rerror_rate', 'duration', 'flag', 'hot', 'is_guest_login', 'is_host_login', 'land', 'logged_in', 'num_access_files', 'num_compromised', 'num_failed_logins', 'num_outbound_cmds', 'num_root', 'num_shells', 'protocol_type', 'rerror_rate', 'same_srv_rate', 'serror_rate', 'src_bytes', 'srv_count', 'srv_diff_host_rate', 'srv_serror_rate', 'su_attempted', 'urgent']
# targets:  ['normal.', 'other.']
# loss:  0.9415244282722474
# accuracy:  0.1209

# %%
pop
# Out:
# [['num_compromised',
#   'is_guest_login',
#   'dst_host_same_srv_rate',
#   'srv_count',
#   'flag',
#   'is_host_login',
#   'num_failed_logins',
#   'urgent',
#   'num_access_files',
#   'protocol_type',
#   'same_srv_rate',
#   'dst_host_serror_rate',
#   'dst_bytes',
#   'num_outbound_cmds',
#   'dst_host_srv_rerror_rate',
#   'dst_host_count',
#   'rerror_rate',
#   'diff_srv_rate',
#   'num_shells',
#   'serror_rate',
#   'srv_diff_host_rate',
#   'dst_host_diff_srv_rate',
#   'dst_host_same_src_port_rate',
#   'hot',
#   'srv_serror_rate',
#   'count',
#   'src_bytes',
#   'dst_host_rerror_rate',
#   'dst_host_srv_count',
#   'num_root',
#   'duration',
#   'logged_in',
#   'su_attempted',
#   'dst_host_srv_diff_host_rate',
#   'land'],
#  ['num_compromised',
#   'is_guest_login',
#   'dst_host_same_srv_rate',
#   'srv_count',
#   'flag',
#   'is_host_login',
#   'num_failed_logins',
#   'urgent',
#   'num_access_files',
#   'protocol_type',
#   'same_srv_rate',
#   'dst_host_serror_rate',
#   'dst_bytes',
#   'num_outbound_cmds',
#   'dst_host_srv_rerror_rate',
#   'dst_host_count',
#   'rerror_rate',
#   'diff_srv_rate',
#   'num_shells',
#   'serror_rate',
#   'srv_diff_host_rate',
#   'dst_host_diff_srv_rate',
#   'dst_host_same_src_port_rate',
#   'hot',
#   'srv_serror_rate',
#   'count',
#   'src_bytes',
#   'dst_host_rerror_rate',
#   'dst_host_srv_count',
#   'num_root',
#   'duration',
#   'logged_in',
#   'su_attempted',
#   'dst_host_srv_diff_host_rate',
#   'land'],
#  ['num_compromised',
#   'is_guest_login',
#   'dst_host_same_srv_rate',
#   'srv_count',
#   'flag',
#   'is_host_login',
#   'num_failed_logins',
#   'urgent',
#   'num_access_files',
#   'protocol_type',
#   'same_srv_rate',
#   'dst_host_serror_rate',
#   'dst_bytes',
#   'num_outbound_cmds',
#   'dst_host_srv_rerror_rate',
#   'dst_host_count',
#   'rerror_rate',
#   'diff_srv_rate',
#   'num_shells',
#   'serror_rate',
#   'srv_diff_host_rate',
#   'dst_host_diff_srv_rate',
#   'dst_host_same_src_port_rate',
#   'hot',
#   'srv_serror_rate',
#   'count',
#   'src_bytes',
#   'dst_host_rerror_rate',
#   'dst_host_srv_count',
#   'num_root',
#   'duration',
#   'logged_in',
#   'su_attempted',
#   'dst_host_srv_diff_host_rate',
#   'land']]
